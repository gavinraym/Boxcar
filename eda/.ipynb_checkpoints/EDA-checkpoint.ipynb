# %% [raw]
# As I approach this problem, my initial question is: can I determine a Perfect Score Distribution? What I mean by this is, if a player was clairvoyent and knew the outcome of every dice roll before rolling, how would they score? To find out, I created PerfectVP which chooses to roll every time regardless of any other factor. The results of this virtual player will be the best possible scores, as long as we treat each round like a win. Before evaluations of PerfectVP can begin, however, we must set some standards for testing. Mainly, how many times must we run our simulation and how many times must we bootstrap the results of our simulation before we can confidently report on a VP's distribution.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import seaborn as sea
from scipy.stats import norm, binom
from etc import *

# %% [raw]
# This graph shows mean score for samples of varying batch sizes, ranging from 100 to 6000 samples per batch. The blue dots represent the variance in sample means for each batch size. For our purposes moving forward, I have decided to use batch sizes of 4k samples.

# %%
df = pd.read_csv('../game/data/batchtests.csv')
mean = df.groupby('batch_size').mean()
std = df.groupby('batch_size').var()
fig, ax = plt.subplots()
ax = sea.scatterplot(
    df['batch_size'], 
    df['mean'], 
    alpha=.5,
    label='Test mean')
ax = sea.scatterplot(mean['mean'].index,mean['mean'],color = 'r',label='Avg test mean')
ax = sea.scatterplot(std['mean'].index,std['mean'],color='b',label='Variance of tests')
plt.ylim(bottom=0, top=610);
plt.legend()
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.set_ylabel('Points', fontsize=16)
ax.set_xlabel('Number of samples per test.', fontsize=16)
fig.suptitle('How many samples should be taken?', fontsize=20)
ax.axvline(5000, color='k', linestyle=':')
ax.text(5000,150, '|<---5k samples needed')
;
# Out:
# ''

# %% [raw]
# Now that we know what sample size to use, let's try and narrow the spread of our distribution using the bootstrap method.
#
# The file perfect.csv contains 4000 scores calculated using PerfectVP.

# %%
scores = pd.read_csv('../game/data/perfect.csv')
xplots = []
yplots = []
for bootstrap_size in range(100, 6000, 100):
    for plots in range(500):
        xplots.append(bootstrap_size)
        yplots.append(
            np.random.choice(
            a=scores['score'],
            size=bootstrap_size,
            replace=True).mean()
        )   
        
df = pd.DataFrame(zip(xplots, yplots), columns=['boot_size','mean'])
mean = df.groupby('boot_size').mean()
std = df.groupby('boot_size').var()

fig, ax = plt.subplots()
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax = sea.scatterplot(xplots,yplots,alpha=.5,label='Test mean')
ax = sea.scatterplot(mean['mean'].index,mean['mean'],color ='r',label='Avg test mean')
ax = sea.scatterplot(std['mean'].index,std['mean'],color ='b',label='Variance of tests')
plt.ylim(bottom=0, top=610);
plt.legend()
ax.set_ylabel('Points', fontsize=16)
ax.set_xlabel('Number of bootstraps per sample.', fontsize=16)
fig.suptitle('How many bootstraps should be performed?', fontsize=20)
ax.axvline(5000, color='k', linestyle=':')
ax.text(5000,150, '|<---5k bootstraps needed')
;
# Out:
# ''

# %%
fig.ax

# %% [raw]
# Now that we know how many samples to take, and how many bootstraps to do, let's plot some distributions!

# %%
def get_dist(df):
    mean = []
    std = []
    for _ in range(5000):
        boot = np.random.choice(a=df['score'],size=5000,replace=True)
        mean.append(boot.mean())
        std.append(boot.std())
    return norm(np.mean(mean), np.mean(std))

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 1000, num=1000)

df = pd.read_csv('../game/data/perfect.csv')
ax.plot(x,get_dist(df).pdf(x),linewidth=2,label='VP: Perfect')
ax.axvline(df['score'].mean(),color='C0',linestyle=':')

df1 = pd.read_csv('../game/data/wyatte.csv')
df1.score.where(df.outcome,0,inplace=True)
ax.plot(x,get_dist(df1).pdf(x),linewidth=2,label='VP: Wyatte')
ax.axvline(df1['score'].mean(),color='C1',linestyle=':')

df2 = pd.read_csv('../game/data/random.csv')
df2.score.where(df.outcome,0,inplace=True)
ax.plot(x, get_dist(df2).pdf(x), linewidth=2, label='VP: Random')
ax.axvline(df2['score'].mean(),color='C2',linestyle=':')

df3 = pd.read_csv('../game/data/karen.csv')
df3.score.where(df.outcome,0,inplace=True)
ax.plot(x, get_dist(df3).pdf(x), linewidth=2, label='VP: Karen')
ax.axvline(df3['score'].mean(),color='C3',linestyle=':')

ax.set_xlim(0,1000)
ax.legend()
ax.set_ylabel('Probability of scoring.', fontsize=16)
ax.set_xlabel('Points gained per round.', fontsize=16)
fig.suptitle('Distributions of VPs.', fontsize=20)
;
# Out:
# ''
