# %% [raw]
# As I approach this problem, my initial question is: can I determine a Perfect Score Distribution? What I mean by this is, if a player was clairvoyent and knew the outcome of every dice roll before rolling, what would they score? To find out, I adapted Boxcar to write the scores of every game regardless of the game's outcome. Because a Boxcar round is lost by not scoring on a roll, the player's score at that point is still the maximum that could have been gained from the round, had they decided to not roll. See the results of the Perfect Player test below.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import seaborn as sea
from scipy.stats import norm

# %%
pd_1_100 = pd.read_csv('boxcar/data/perfect1_100.csv')
pd_100_100 = pd.read_csv('boxcar/data/perfect100_100.csv')
pd_1000_100 = pd.read_csv('boxcar/data/perfect1000_100.csv')
pd_5000_100 = pd.read_csv('boxcar/data/perfect5000_100.csv')

np_1_100 = np.fromfile('boxcar/data/perfect1_100.csv')
np_100_100 = np.fromfile('boxcar/data/perfect100_100.csv')
np_1000_100 = np.fromfile('boxcar/data/perfect1000_100.csv')
np_5000_100 = np.fromfile('boxcar/data/perfect5000_100.csv', dtype=float)

# %%
np_5000_1 = np.fromfile('../game/data/prelim/perfect5000_1.csv', sep='\n',dtype=int)
mean = np_5000_1.mean()
std = np_5000_1.std()
b = norm(mean, std)
x = np.arange(350, 750)
y = b.pdf(x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-235f6ad67c23> in <module>
# ----> 1 np_5000_1 = np.fromfile('../game/data/prelim/perfect5000_1.csv', sep='\n',dtype=int)
#       2 mean = np_5000_1.mean()
#       3 std = np_5000_1.std()
#       4 b = norm(mean, std)
#       5 x = np.arange(350, 750)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../game/data/prelim/perfect5000_1.csv'

# %%
cd
# Out:
# /home/gavin/Boxcar/game

# %%
plt.plot(x,y)

# %%
batchtest = pd.read_csv('data/prelim/batchtests.csv')
mean_per_test = batchtest.groupby('batch_size').mean()
std_per_test = batchtest.groupby('batch_size').var()
fig = plt.figure()
fig.ax = sea.scatterplot(
    batchtest['batch_size'], 
    batchtest['mean'], 
    alpha=.5,
    label='Test mean')
fig.ax = sea.scatterplot(
    mean_per_test['mean'].index,
    mean_per_test['mean'],
    color = 'r',
    label='Avg test mean')
fig.ax = sea.scatterplot(
    std_per_test['mean'].index,
    std_per_test['mean'],
    color = 'b',
    label='Variance of tests')
plt.ylim(bottom=0, top=600);
plt.legend()

fig.ax.set_ylabel('Points', fontsize=16)
fig.ax.set_xlabel('Number of samples per test.', fontsize=16)
fig.suptitle('How many samples should be taken?', fontsize=20)
fig.ax.axvline(4000, color='k', ds='steps')
fig.ax.text(4000,150, '|<---4k samples needed')
;
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-6de813ce2508> in <module>
#      24 fig.ax.set_xlabel('Number of samples per test.', fontsize=16)
#      25 fig.suptitle('How many samples should be taken?', fontsize=20)
# ---> 26 fig.ax.axvline(4000, color='k', ds='steps')
#      27 fig.ax.text(4000,150, '|<---4k samples needed')
#      28 ("")
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     876
#     877         trans = self.get_xaxis_transform(which='grid')
# --> 878         l = mlines.Line2D([x, x], [ymin, ymax], transform=trans, **kwargs)
#     879         self.add_line(l)
#     880         self.autoscale_view(scalex=scalex, scaley=False)
#
# ...

# %%
batchtest = pd.read_csv('data/prelim/batchtests10.csv')
mean_per_test = batchtest.groupby('batch_size').mean()
fig = plt.figure()
fig.ax = plt.scatter(batchtest['batch_size'], batchtest['mean'], alpha=.5)
fig.ax = plt.scatter(mean_per_test['mean'].index, mean_per_test['mean'], color = 'r')
np.std( mean_per_test['mean'])
# Out:
# 2.207157391306753

# %%
batchtest = pd.read_csv('data/prelim/batchtests.csv')

# %%
plt.scatter(batchtest['batch_size'], batchtest['mean'], alpha=.5)

# %%
plt.scatter(teststest['mean'], teststest['test_size'], alpha=.2)

# %%
perfect_1_100.hist(grid=False, sharey=True, color = 'g')
perfect_100_100.hist(grid=False, sharey=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5c326f4f60>]],
#       dtype=object)

# %%
ax = sea.distplot(perfect_5000_100, color='g')

# %%
fig, ax = plt.subplots(1,1)
ax = sea.distplot(perfect_1_100, color='g')
ax = sea.distplot(perfect_100_100, color='k')
ax = sea.distplot(perfect_1000_100, color='b')

# %%
x = np.linspace(0, 1000, 1000)
y = xone.ppf(x)

# %%
perfect_1_100 = pd.read_csv('boxcar/data/perfect1_100.csv')
perfect_100_100 = pd.read_csv('boxcar/data/perfect100_100.csv')
perfect_1000_100 = pd.read_csv('boxcar/data/perfect1000_100.csv')
perfect_5000_100 = pd.read_csv('boxcar/data/perfect5000_100.csv')

xone_np = np.fromfile('boxcar/data/perfect1_100.csv')

xone = binom(xone_np.mean(), xone_np.std() )
